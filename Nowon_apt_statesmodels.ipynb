# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
import math

# %%
data_m = pd.read_csv('C:/Users/1102j/anaconda/dataScience/project/apt_data_month_added.csv', thousands=',', encoding='utf-8')
data_m
# Out:
#                 시군구      번지   본번  부번       단지명 전월세구분  전용면적(㎡)    계약년월  계약일  \
# 0     서울특별시 노원구 공릉동  683-30  683  30  (683-30)    월세    20.00  202001    6
# 1     서울특별시 노원구 공릉동  683-30  683  30  (683-30)    월세    20.00  202007    9
# 2     서울특별시 노원구 공릉동  683-30  683  30  (683-30)    월세    20.00  202008    6
# 3     서울특별시 노원구 공릉동  683-30  683  30  (683-30)    월세    20.00  202008   21
# 4     서울특별시 노원구 공릉동  683-30  683  30  (683-30)    월세    20.00  202009    7
# ...             ...     ...  ...  ..       ...   ...      ...     ...  ...
# 3997  서울특별시 노원구 하계동     270  270   0        현대    월세    72.20  202009   10
# 3998  서울특별시 노원구 하계동     270  270   0        현대    월세    72.20  202009   10
# 3999  서울특별시 노원구 하계동     270  270   0        현대    월세    84.95  202010   10
# 4000  서울특별시 노원구 하계동     270  270   0        현대    월세    84.95  202011   23
# 4001  서울특별시 노원구 하계동     270  270   0        현대    월세    84.95  202012   23
#
# ...

# %%
data_y = pd.read_csv('C:/Users/1102j/anaconda/dataScience/project/apt_data_year(3법추가본).csv', thousands=',', encoding='utf-8')
data_y
# Out:
#                  시군구     번지   본번  부번      단지명 전월세구분  전용면적(㎡)    계약년월  계약일  \
# 0      서울특별시 노원구 공릉동  404-3  404   3    건영아파트    전세    84.75  202007   18
# 1      서울특별시 노원구 공릉동    744  744   0  건영장미아파트    전세    84.88  202002    8
# 2      서울특별시 노원구 공릉동    744  744   0  건영장미아파트    전세    84.88  202007    1
# 3      서울특별시 노원구 공릉동    744  744   0  건영장미아파트    전세    59.87  202007   11
# 4      서울특별시 노원구 공릉동    744  744   0  건영장미아파트    전세    59.87  202007   13
# ...              ...    ...  ...  ..      ...   ...      ...     ...  ...
# 10533  서울특별시 노원구 하계동    270  270   0       현대    전세    84.95  202010   29
# 10534  서울특별시 노원구 하계동    270  270   0       현대    전세    84.95  202011    7
# 10535  서울특별시 노원구 하계동    270  270   0       현대    전세    84.95  202012    2
# 10536  서울특별시 노원구 하계동    270  270   0       현대    전세    84.95  202012    9
# 10537  서울특별시 노원구 하계동    270  270   0       현대    전세    71.68  202012   22
#
#        전월세(만원)  ...  대형마트   백화점   cctv    주차대수  브랜드  복도유형  난방방식   승강기  주차관제  \
# ...

# %% [markdown]
# # 월세

# %%
data_m = data_m.dropna()

# %%
xm = data_m[['전용면적(㎡)', '층', '건축년도', '초등학교', '병원', '공원', '대형마트', '백화점', 'cctv', '주차대수', '브랜드', '주차관제', '승강기', '복도유형', '난방방식']]
ym = data_m[['전월세(만원)']]

# %%
ym['전월세(만원)'] = np.log(ym)
# Out:
# <ipython-input-46-9c8715ba90b9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ym['전월세(만원)'] = np.log(ym)

# %%
model = sm.OLS(ym, xm)
result = model.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                전월세(만원)   R-squared (uncentered):                   0.955
# Model:                            OLS   Adj. R-squared (uncentered):              0.955
# Method:                 Least Squares   F-statistic:                              4828.
# Date:                Sun, 06 Jun 2021   Prob (F-statistic):                        0.00
# Time:                        17:23:49   Log-Likelihood:                         -34534.
# No. Observations:                3448   AIC:                                  6.910e+04
# Df Residuals:                    3433   BIC:                                  6.919e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# # 월세 (조정)

# %%
# P값이 높은 행 삭제
xm = data_m[['전용면적(㎡)', '층', '건축년도', '병원', '공원', '대형마트', 'cctv', '주차대수', '브랜드', '복도유형', '난방방식']]
ym = data_m[['전월세(만원)']]

# %%
ym['전월세(만원)'] = np.log(ym)
# Out:
# <ipython-input-20-9c8715ba90b9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ym['전월세(만원)'] = np.log(ym)

# %%
xm['공원'] = xm['공원'] ** 2
xm['전용면적(㎡)'] = xm['전용면적(㎡)'] ** 2
xm['층'] = xm['층'] ** 2
xm['건축년도'] = xm['건축년도'] ** 2
# Out:
# <ipython-input-25-607a29d3bfe8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xm['공원'] = xm['공원'] ** 2
# <ipython-input-25-607a29d3bfe8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xm['전용면적(㎡)'] = xm['전용면적(㎡)'] ** 2
# <ipython-input-25-607a29d3bfe8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
model_m = sm.OLS(ym, xm)
result_m = model_m.fit()

# %%
result_m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                전월세(만원)   R-squared (uncentered):                   0.949
# Model:                            OLS   Adj. R-squared (uncentered):              0.949
# Method:                 Least Squares   F-statistic:                              5870.
# Date:                Sun, 06 Jun 2021   Prob (F-statistic):                        0.00
# Time:                        17:24:15   Log-Likelihood:                         -34725.
# No. Observations:                3448   AIC:                                  6.947e+04
# Df Residuals:                    3437   BIC:                                  6.954e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# # 전세

# %%
data_y = data_y.dropna()

# %%
xy = data_y[['전용면적(㎡)', '층', '건축년도', '초등학교', '병원', '공원', '대형마트', '백화점', 'cctv', '주차대수', '브랜드', '주차관제', '승강기', '복도유형', '난방방식', '3법']]
yy = data_y[['전월세(만원)']]

# %%
yy['전월세(만원)'] = np.log(yy)
yy
# Out:
# <ipython-input-106-16a4bfcd1bb0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yy['전월세(만원)'] = np.log(yy)
#          전월세(만원)
# 1      10.463103
# 2      10.596635
# 3      10.203592
# 4      10.239960
# 5      10.596635
# ...          ...
# 10533  11.002100
# 10534  10.645425
# 10535  11.082143
# 10536  10.540064
# 10537  10.714418
#
# [9490 rows x 1 columns]

# %%
model_y = sm.OLS(yy, xy)
result_y = model_y.fit()

# %%
result_y.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                전월세(만원)   R-squared (uncentered):                   0.951
# Model:                            OLS   Adj. R-squared (uncentered):              0.951
# Method:                 Least Squares   F-statistic:                          1.160e+04
# Date:                Sun, 06 Jun 2021   Prob (F-statistic):                        0.00
# Time:                        17:24:23   Log-Likelihood:                         -96813.
# No. Observations:                9490   AIC:                                  1.937e+05
# Df Residuals:                    9474   BIC:                                  1.938e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# # 전세 (조정)

# %%
# P값 높은 행 삭제
xy = data_y[['전용면적(㎡)', '층', '건축년도', '병원', '공원', '대형마트', '백화점', '주차대수', '브랜드', '복도유형', '난방방식']]
yy = data_y[['전월세(만원)']]

# %%
yy['전월세(만원)'] = np.log(yy)
# Out:
# <ipython-input-33-2e1966bb2513>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yy['전월세(만원)'] = np.log(yy)

# %%
xy['공원'] = xy['공원'] ** 2
xy['전용면적(㎡)'] = xy['전용면적(㎡)'] ** 2
xy['층'] = xy['층'] ** 2
xy['건축년도'] = xy['건축년도'] ** 2
xy['층'] = xy['층'] ** 2
# Out:
# <ipython-input-230-0315feb7abc5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xy['공원'] = xy['공원'] ** 2
# <ipython-input-230-0315feb7abc5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xy['전용면적(㎡)'] = xy['전용면적(㎡)'] ** 2
# <ipython-input-230-0315feb7abc5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
model_y = sm.OLS(yy, xy)
result_y = model_y.fit()

# %%
result_y.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                전월세(만원)   R-squared (uncentered):                   0.999
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                          1.395e+06
# Date:                Sun, 06 Jun 2021   Prob (F-statistic):                        0.00
# Time:                        17:24:28   Log-Likelihood:                         -330.40
# No. Observations:                9490   AIC:                                      682.8
# Df Residuals:                    9479   BIC:                                      761.5
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# # 월세(데이터추가)

# %%
data_m = pd.read_csv('C:/Users/1102j/anaconda/dataScience/project/month_nowon.csv', thousands=',', encoding='euckr')
data_m
# Out:
#                 시군구      번지   본번  부번       단지명 전월세구분  전용면적(㎡)    계약년월  계약일  \
# 0     서울특별시 노원구 공릉동  683-30  683  30  (683-30)    월세    20.00  202001    6
# 1     서울특별시 노원구 공릉동  683-30  683  30  (683-30)    월세    20.00  202007    9
# 2     서울특별시 노원구 공릉동  683-30  683  30  (683-30)    월세    20.00  202008    6
# 3     서울특별시 노원구 공릉동  683-30  683  30  (683-30)    월세    20.00  202008   21
# 4     서울특별시 노원구 공릉동  683-30  683  30  (683-30)    월세    20.00  202009    7
# ...             ...     ...  ...  ..       ...   ...      ...     ...  ...
# 3997  서울특별시 노원구 하계동     270  270   0        현대    월세    72.20  202009   10
# 3998  서울특별시 노원구 하계동     270  270   0        현대    월세    72.20  202009   10
# 3999  서울특별시 노원구 하계동     270  270   0        현대    월세    84.95  202010   10
# 4000  서울특별시 노원구 하계동     270  270   0        현대    월세    84.95  202011   23
# 4001  서울특별시 노원구 하계동     270  270   0        현대    월세    84.95  202012   23
#
# ...

# %%
data_m.난방방식 = data_m.난방방식.replace('개별난방', 1)
data_m.난방방식 = data_m.난방방식.replace('지역난방', 0)
data_m.난방방식 = data_m.난방방식.replace('중앙난방', 0)

# %%
data_m.to_csv('노원월세.csv', index=False, encoding='euckr')

# %%
data_m = pd.read_csv('C:/Users/1102j/anaconda/dataScience/project/노원월세.csv', thousands=',', encoding='euckr')
data_m
# Out:
#                 시군구      번지   본번  부번       단지명 전월세구분  전용면적(㎡)    계약년월  계약일  \
# 0     서울특별시 노원구 공릉동  683-30  683  30  (683-30)    월세    20.00  202001    6
# 1     서울특별시 노원구 공릉동  683-30  683  30  (683-30)    월세    20.00  202007    9
# 2     서울특별시 노원구 공릉동  683-30  683  30  (683-30)    월세    20.00  202008    6
# 3     서울특별시 노원구 공릉동  683-30  683  30  (683-30)    월세    20.00  202008   21
# 4     서울특별시 노원구 공릉동  683-30  683  30  (683-30)    월세    20.00  202009    7
# ...             ...     ...  ...  ..       ...   ...      ...     ...  ...
# 3997  서울특별시 노원구 하계동     270  270   0        현대    월세    72.20  202009   10
# 3998  서울특별시 노원구 하계동     270  270   0        현대    월세    72.20  202009   10
# 3999  서울특별시 노원구 하계동     270  270   0        현대    월세    84.95  202010   10
# 4000  서울특별시 노원구 하계동     270  270   0        현대    월세    84.95  202011   23
# 4001  서울특별시 노원구 하계동     270  270   0        현대    월세    84.95  202012   23
#
# ...

# %%
data_m = data_m.dropna()

# %%
xm = data_m[['전용면적(㎡)', '건축년도', '병원', '공원', '대형마트', '백화점 ', 'cctv', '브랜드', '주차관제', '승강기', '복도유형', '일반관리', '경비관리']]
ym = data_m[['전월세(만원)']]

# %%
ym['전월세(만원)'] = np.log(ym)
# Out:
# <ipython-input-79-9c8715ba90b9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ym['전월세(만원)'] = np.log(ym)

# %%
model_x = sm.OLS(ym, xm)
result_x = model_x.fit()

# %%
result_x.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                전월세(만원)   R-squared (uncentered):                   0.999
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                          3.740e+05
# Date:                Sun, 06 Jun 2021   Prob (F-statistic):                        0.00
# Time:                        17:40:27   Log-Likelihood:                         -213.78
# No. Observations:                3287   AIC:                                      453.6
# Df Residuals:                    3274   BIC:                                      532.8
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
