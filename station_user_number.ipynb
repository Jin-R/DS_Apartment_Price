# %%
import numpy as np
import pandas as pd

# %%
station = pd.read_csv('C:/Users/1102j/anaconda/dataScience/project/역이용.csv', thousands=',')
station
# Out:
#        호선명     역명                  행정구역     월   승하차      월요일      화요일  \
# 0      1호선     서울          ___회현동(서울중구)  연간합계  총승하차  114,437  114,561
# 1      1호선     시청           ___명동(서울중구)  연간합계  총승하차   59,927   60,286
# 2      1호선     종각  ___종로1·2·3·4가동(서울종로)  연간합계  총승하차   97,593   98,370
# 3      1호선   종로3가  ___종로1·2·3·4가동(서울종로)  연간합계  총승하차   69,314   70,480
# 4      1호선   종로5가      ___종로5·6가동(서울종로)  연간합계  총승하차   58,776   58,538
# ..     ...    ...                   ...   ...   ...      ...      ...
# 579  인천2호선  모래내시장         ___구월1동(인천남동)  연간합계  총승하차        -        -
# 580  인천2호선     만수         ___만수1동(인천남동)  연간합계  총승하차        -        -
# 581  인천2호선   남동구청         ___만수1동(인천남동)  연간합계  총승하차        -        -
# 582  인천2호선  인천대공원        ___장수서창동(인천남동)  연간합계  총승하차        -        -
# 583  인천2호선     운연        ___장수서창동(인천남동)  연간합계  총승하차        -        -
#
#          수요일      목요일      금요일     토요일      일요일    모든요일
# 0    117,534  132,684  108,452  79,521  115,036  111754
# ...

# %%
station[station['행정구역'].str.contains('노원')]
# Out:
#      호선명    역명             행정구역     월   승하차     월요일     화요일     수요일     목요일  \
# 94   4호선   당고개  ___상계3·4동(서울노원)  연간합계  총승하차  28,527  28,161  28,189  28,960
# 95   4호선    상계    ___상계5동(서울노원)  연간합계  총승하차  44,805  44,485  44,190  45,465
# 96   4호선    노원    ___상계2동(서울노원)  연간합계  총승하차  50,288  51,054  50,347  54,126
# 137  경원선    석계    ___월계1동(서울노원)  연간합계  총승하차       -       -       -       -
# 138  경원선   광운대    ___월계1동(서울노원)  연간합계  총승하차       -       -       -       -
# 139  경원선    월계    ___월계2동(서울노원)  연간합계  총승하차       -       -       -       -
# 456  6호선    석계    ___월계1동(서울노원)  연간합계  총승하차  30,529  30,274  29,995  30,685
# 457  6호선  태릉입구    ___공릉1동(서울노원)  연간합계  총승하차  13,964  13,982  13,901  14,194
# 458  6호선   화랑대    ___공릉2동(서울노원)  연간합계  총승하차  26,729  26,492  26,252  26,379
# 462  7호선   수락산    ___상계1동(서울노원)  연간합계  총승하차  29,651  29,488  29,309  30,019
# 463  7호선    마들    ___상계1동(서울노원)  연간합계  총승하차  26,874  26,646  26,709  27,399
# ...
